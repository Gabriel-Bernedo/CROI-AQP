# %% [markdown]
# # Importar modulo de Matlab para python

# %%
# %pip install matlabengine
import matlab.engine
eng = matlab.engine.start_matlab()

work_path = r'C:\Users\ASUS\Documents\Github\CROI-AQP\F_MATLAB'

eng.addpath(work_path)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# A partir de aqui puede codear feliz, haga las pruebas requeridas usando esta plantilla si desea XD

# %%
print(f" 100 | 10 : ROI = {eng.CalcularROI(100,10)}")
# Out:
#  100 | 10 : ROI = 10
